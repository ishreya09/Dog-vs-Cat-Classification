# %%
#importing dependencies
import os
import numpy as np
from PIL import Image
import matplotlib.image as mpimg
import cv2
import matplotlib.pyplot as plt

# %%
path,dirs,files= next(os.walk('PetImages\Cat'))
filecount=len(files)
print("Number of cat images are ",filecount)
# Out:
# Number of cat images are  12491

# %%
path,dirs,files= next(os.walk('PetImages\Dog'))
filecount=len(files)
print("Number of cat images are ",filecount)
# Out:
# Number of cat images are  12470

# %% [markdown]
# Printing name of Images

# %%
file_names= os.listdir("PetImages\Dog")
file_names
# Out:
# ['0.jpg',
#  '1.jpg',
#  '10.jpg',
#  '100.jpg',
#  '1000.jpg',
#  '10000.jpg',
#  '10001.jpg',
#  '10002.jpg',
#  '10003.jpg',
#  '10004.jpg',
#  '10005.jpg',
#  '10006.jpg',
#  '10007.jpg',
#  '10008.jpg',
#  '10009.jpg',
#  '1001.jpg',
#  '10010.jpg',
#  '10011.jpg',
#  '10012.jpg',
#  '10013.jpg',
#  '10014.jpg',
#  '10015.jpg',
#  '10016.jpg',
#  '10017.jpg',
#  '10018.jpg',
#  '10019.jpg',
#  '1002.jpg',
#  '10020.jpg',
#  '10021.jpg',
#  '10022.jpg',
#  '10023.jpg',
#  '10024.jpg',
#  '10025.jpg',
#  '10026.jpg',
#  '10027.jpg',
#  '10028.jpg',
#  '10029.jpg',
#  '1003.jpg',
#  '10030.jpg',
#  '10031.jpg',
#  '10032.jpg',
#  '10033.jpg',
#  '10034.jpg',
#  '10035.jpg',
#  '10036.jpg',
#  '10037.jpg',
#  '10038.jpg',
#  '10039.jpg',
#  '1004.jpg',
#  '10040.jpg',
#  '10041.jpg',
#  '10042.jpg',
#  '10043.jpg',
#  '10044.jpg',
#  '10045.jpg',
#  '10046.jpg',
#  '10047.jpg',
#  '10048.jpg',
#  '10049.jpg',
#  '1005.jpg',
#  '10050.jpg',
#  '10051.jpg',
#  '10052.jpg',
# ...

# %%
file_names= os.listdir("PetImages\Cat")
file_names
# Out:
# ['0.jpg',
#  '1.jpg',
#  '10.jpg',
#  '100.jpg',
#  '1000.jpg',
#  '10000.jpg',
#  '10001.jpg',
#  '10002.jpg',
#  '10003.jpg',
#  '10004.jpg',
#  '10005.jpg',
#  '10006.jpg',
#  '10007.jpg',
#  '10008.jpg',
#  '10009.jpg',
#  '1001.jpg',
#  '10010.jpg',
#  '10011.jpg',
#  '10012.jpg',
#  '10013.jpg',
#  '10014.jpg',
#  '10015.jpg',
#  '10016.jpg',
#  '10017.jpg',
#  '10018.jpg',
#  '10019.jpg',
#  '1002.jpg',
#  '10020.jpg',
#  '10021.jpg',
#  '10022.jpg',
#  '10023.jpg',
#  '10024.jpg',
#  '10025.jpg',
#  '10026.jpg',
#  '10027.jpg',
#  '10028.jpg',
#  '10029.jpg',
#  '1003.jpg',
#  '10030.jpg',
#  '10031.jpg',
#  '10032.jpg',
#  '10033.jpg',
#  '10034.jpg',
#  '10035.jpg',
#  '10036.jpg',
#  '10037.jpg',
#  '10038.jpg',
#  '10039.jpg',
#  '1004.jpg',
#  '10040.jpg',
#  '10041.jpg',
#  '10042.jpg',
#  '10043.jpg',
#  '10044.jpg',
#  '10045.jpg',
#  '10046.jpg',
#  '10047.jpg',
#  '10048.jpg',
#  '10049.jpg',
#  '1005.jpg',
#  '10050.jpg',
#  '10051.jpg',
#  '10052.jpg',
# ...

# %% [markdown]
# Displaying Dogs and cat images

# %%
img= mpimg.imread('PetImages/Cat/1.jpg')
plt.imshow(img)
print(img.shape)
# Out:
# (281, 300, 3)

# %%
img= mpimg.imread('PetImages/Dog/10.jpg')
plt.imshow(img)
print(img.shape)
# Out:
# (293, 269, 3)

# %% [markdown]
# Images are not of same size
#
# All images are RGB images

# %% [markdown]
# # Resizing all the images

# %% [markdown]
# We will resize the images and store it somewhere.

# %%
os.mkdir("Dataset") # contains resized images

# %%
original_folder= "PetImages/"
resized_folder="Dataset/"

# %%
# for cats
folder=original_folder+"Cat/"
for i in range(1000):
    filename= os.listdir(folder)[i]
    img_path=folder+filename
    img= Image.open(img_path)
    img= img.resize((224,224))
    img=img.convert('RGB')
    new_path=resized_folder+"cat."+filename
    img.save(new_path)

# %%
# for dogs
folder=original_folder+"Dog/"
for i in range(1000):
    filename= os.listdir(folder)[i]
    img_path=folder+filename
    img= Image.open(img_path)
    img= img.resize((224,224))
    img=img.convert('RGB')
    new_path=resized_folder+"dog."+filename
    img.save(new_path)

# %%
# display resized dog img
img= mpimg.imread("Dataset/dog.10003.jpg")
plt.imshow(img)

# %%
# display resized cat img
img= mpimg.imread("Dataset/cat.10006.jpg")
plt.imshow(img)

# %% [markdown]
# # Creating Labels for resized images for dogs and cats
#
# cat -0
#
# dog- 1
