# %%
#importing dependencies
import os
import numpy as np
from PIL import Image
import matplotlib.image as mpimg
import cv2
import matplotlib.pyplot as plt
import glob

# %%
# display resized dog img
img= mpimg.imread("Dataset/dog.10003.jpg")
plt.imshow(img)

# %%
# display resized cat img
img= mpimg.imread("Dataset/cat.10006.jpg")
plt.imshow(img)

# %%
labels=[]
filenames= os.listdir("Dataset/")

for i in range(10000):
    file_name=filenames[i]
    label=file_name[0:3]
    if(label=="dog"):
        labels.append(1)
    else:
        labels.append(0)

# %%
list(zip(filenames[0:5],labels[0:5]))
# Out:
# [('cat.0.jpg', 0),
#  ('cat.1.jpg', 0),
#  ('cat.10.jpg', 0),
#  ('cat.100.jpg', 0),
#  ('cat.1000.jpg', 0)]

# %%
list(zip(filenames[-5:],labels[-5:]))
# Out:
# [('dog.3255.jpg', 1),
#  ('dog.3256.jpg', 1),
#  ('dog.3257.jpg', 1),
#  ('dog.3258.jpg', 1),
#  ('dog.3259.jpg', 1)]

# %%
values,counts= np.unique(labels,return_counts=True)

# %%
print(values)
print(counts)
# Out:
# [0 1]
# [5000 5000]

# %%
image_dir= "Dataset/"
image_ext=['png','jpg']

files=[]

[files.extend(glob.glob(image_dir+"*."+e)) for e in image_ext]
dog_cat_img= np.asarray([cv2.imread(file) for file in files])
